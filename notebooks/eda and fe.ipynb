# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Documents/forest.csv',header=1)

# %%
# data cleaning

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
df.loc[:122,'Region']=0

# %%
df.loc[122:,'Region']=1

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire        0.0
# 1  not fire        0.0
# 2  not fire        0.0
# 3  not fire        0.0
# 4  not fire        0.0

# %%
df.dropna(inplace=True)

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [day, month, year, Temperature,  RH,  Ws, Rain , FFMC, DMC, DC, ISI, BUI, FWI, Classes  , Region]
# Index: []

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#    index day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  \
# 0      0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4
# 1      1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9
# 2      2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3      3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7
# 4      4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9
#
#    FWI    Classes    Region
# 0  0.5  not fire        0.0
# 1  0.4  not fire        0.0
# 2  0.1  not fire        0.0
# 3    0  not fire        0.0
# 4  0.5  not fire        0.0

# %%
df.drop(122,inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df.drop(columns=['level_0'],inplace=True)

# %%
df.columns=df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['index', 'day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain',
#        'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df['RH']
# Out:
# 0      57
# 1      61
# 2      82
# 3      89
# 4      77
#        ..
# 238    65
# 239    87
# 240    87
# 241    54
# 242    64
# Name: RH, Length: 243, dtype: object

# %%
df[['day','year','Temperature']]
# Out:
#     day  year Temperature
# 0    01  2012          29
# 1    02  2012          29
# 2    03  2012          26
# 3    04  2012          25
# 4    05  2012          27
# ..   ..   ...         ...
# 238  26  2012          30
# 239  27  2012          28
# 240  28  2012          27
# 241  29  2012          24
# 242  30  2012          24
#
# [243 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        243 non-null    int64
#  1   day          243 non-null    object
#  2   month        243 non-null    object
#  3   year         243 non-null    object
#  4   Temperature  243 non-null    object
#  5   RH           243 non-null    object
#  6   Ws           243 non-null    object
#  7   Rain         243 non-null    object
#  8   FFMC         243 non-null    object
#  9   DMC          243 non-null    object
#  10  DC           243 non-null    object
#  11  ISI          243 non-null    object
#  12  BUI          243 non-null    object
#  13  FWI          243 non-null    object
#  14  Classes      243 non-null    object
#  15  Region       243 non-null    float64
# dtypes: float64(1), int64(1), object(14)
# memory usage: 30.5+ KB

# %%
df.head()
# Out:
#    index day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0      0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4
# 1      1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9
# 2      2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3      3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7
# 4      4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire        0.0
# 1  0.4  not fire        0.0
# 2  0.1  not fire        0.0
# 3    0  not fire        0.0
# 4  0.5  not fire        0.0

# %%
df['RH']
# Out:
# 0      57
# 1      61
# 2      82
# 3      89
# 4      77
#        ..
# 238    65
# 239    87
# 240    87
# 241    54
# 242    64
# Name: RH, Length: 243, dtype: object

# %%
df[['Temperature','day','month','year','RH','Ws']]=df[['Temperature','day','month','year','RH','Ws']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        243 non-null    int64
#  1   day          243 non-null    int32
#  2   month        243 non-null    int32
#  3   year         243 non-null    int32
#  4   Temperature  243 non-null    int32
#  5   RH           243 non-null    int32
#  6   Ws           243 non-null    int32
#  7   Rain         243 non-null    object
#  8   FFMC         243 non-null    object
#  9   DMC          243 non-null    object
#  10  DC           243 non-null    object
#  11  ISI          243 non-null    object
#  12  BUI          243 non-null    object
#  13  FWI          243 non-null    object
#  14  Classes      243 non-null    object
#  15  Region       243 non-null    float64
# dtypes: float64(1), int32(6), int64(1), object(8)
# memory usage: 24.8+ KB

# %%
df['Region']=df['Region'].astype(int)

# %%
df.head()
# Out:
#    index  day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  \
# 0      0    1      6  2012           29  57  18     0  65.7  3.4   7.6  1.3
# 1      1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6    1
# 2      2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3
# 3      3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9    0
# 4      4    5      6  2012           27  77  16     0  64.8    3  14.2  1.2
#
#    BUI  FWI      Classes  Region
# 0  3.4  0.5  not fire          0
# 1  3.9  0.4  not fire          0
# 2  2.7  0.1  not fire          0
# 3  1.7    0  not fire          0
# 4  3.9  0.5  not fire          0

# %%
obj=df.select_dtypes(include='object').columns.to_list()

# %%
obj
# Out:
# ['Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes']

# %%
for col in obj:
    if col !='Classes':
        df[col]=df[col].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        243 non-null    int64
#  1   day          243 non-null    int32
#  2   month        243 non-null    int32
#  3   year         243 non-null    int32
#  4   Temperature  243 non-null    int32
#  5   RH           243 non-null    int32
#  6   Ws           243 non-null    int32
#  7   Rain         243 non-null    float64
#  8   FFMC         243 non-null    float64
#  9   DMC          243 non-null    float64
#  10  DC           243 non-null    float64
#  11  ISI          243 non-null    float64
#  12  BUI          243 non-null    float64
#  13  FWI          243 non-null    float64
#  14  Classes      243 non-null    object
#  15  Region       243 non-null    int32
# dtypes: float64(7), int32(7), int64(1), object(1)
# memory usage: 23.9+ KB

# %%
df_copy=df.to_csv('updated_ridge.csv',index=False)

# %%
df=pd.read_csv('updated_ridge.csv')

# %%
df.drop(columns=['index'],inplace=True)

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
df['Classes']=np.where(df['Classes'].str.contains('not fire'),'not fire','fire')

# %%
df['Classes'].value_counts()
# Out:
# Classes
# fire        137
# not fire    106
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI   Classes  Region
# 0  0.5  not fire       0
# 1  0.4  not fire       0
# 2  0.1  not fire       0
# 3  0.0  not fire       0
# 4  0.5  not fire       0

# %%
# df_copy=df.drop(columns=['day','month','year'],inplace=True)
# plt.style.use('seaborn')


df.hist(bins=50,figsize=(20,15));

# %%
percent=df['Classes'].value_counts()

# %%
plt.pie(percent,autopct="%1.1f%%",colors=['lightgreen','orange'],explode=(0.05,0),shadow=True);

# %%
percent=df['Classes'].value_counts(normalize=True)*100

# %%
percent
# Out:
# Classes
# 1    56.378601
# 0    43.621399
# Name: proportion, dtype: float64

# %%
df.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.982248
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  0.875864
# Classes         0.516015 -0.432161 -0.069964 -0.379097  0.769492  0.585658
# ...

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
df_temp=df.loc[df['Region']==1]

# %%
df_temp
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 122           32  71  12   0.7  57.1   2.5   8.2  0.6   2.8  0.2        0
# 123           30  73  13   4.0  55.7   2.7   7.8  0.6   2.9  0.2        0
# 124           29  80  14   2.0  48.7   2.2   7.6  0.3   2.6  0.1        0
# 125           30  64  14   0.0  79.4   5.2  15.4  2.2   5.6  1.0        0
# 126           32  60  14   0.2  77.1   6.0  17.6  1.8   6.5  0.9        0
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...  ...      ...
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0        0
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
#      Region
# 122       1
# 123       1
# 124       1
# 125       1
# ...

# %%
plt.figure(figsize=(10,7))
plt.subplot(1,2,1)
sns.countplot(x='month',data=df,hue='Classes')
# Out:
# <Axes: xlabel='month', ylabel='count'>

# %%
s=df.groupby('month')['Temperature'].mean()

# %%
s.plot(kind='bar')
# Out:
# <Axes: xlabel='month'>

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI   Classes  Region
# 0  0.5  not fire       0
# 1  0.4  not fire       0
# 2  0.1  not fire       0
# 3  0.0  not fire       0
# 4  0.5  not fire       0
